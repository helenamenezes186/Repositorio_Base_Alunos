# %% [markdown]
# Função print()

# %% [markdown]
# a função print () é uma das funções mias importantes e usadas na linguagem python. sua função é, basicamente, exibir mensagens na tela ou envia-las para outro dispositivo, como imprimir dentro de um arquivo de texto. No python 3, print() é uma função interna, de modo que não é necessario importar nenhuma biblioteca para poder utiliza-las, basta chaá-la e passar os argumentos necessarios.

# %%
print("meu primeiro print") # todo texto deve estar entre aspas simples ou duplas
# Out:
# meu primeiro print

# %%
print('meu segundo print')

# %%
print("D'águas") # quando uma palavra conte aspas as aspas iniciais devem ser diferentes

# %%
print(20+15) # o python realiza a operação que está dentro do parenteses

# %%
print('20+15') # a operação entre aspas sera sempre apenas impresa não execultada pois o python entende isso como texto

# %%
print('20+15='20+15)

# %%
n1= '1'
n2= '2'
print(n1+n2) #neste exemplo o python faz a concatenação das 2 strings

# %%
nome= 'helena'
sobrenome= 'menezes'
nome_completo= nome +' ' + sobrenome
print(nome_completo)
